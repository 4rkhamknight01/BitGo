# %%
import json
import requests
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_absolute_error
# %matplotlib inline

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=ETH&tsym=USD&limit=2000')
df = pd.DataFrame(json.loads(res.content)['Data'])
df = df.set_index('time')
df.index = pd.to_datetime(df.index, unit='s')

# %%
df
# Out:
#                high      low     open  ...    close  conversionType  conversionSymbol
# time                                   ...
# 2016-05-21    14.12    13.10    13.73  ...    14.01        multiply               BTC
# 2016-05-22    14.42    13.64    14.01  ...    14.27        multiply               BTC
# 2016-05-23    14.67    13.38    14.27  ...    13.45        multiply               BTC
# 2016-05-24    13.81    11.90    13.45  ...    12.62          direct
# 2016-05-25    13.03    11.71    12.63  ...    12.52        multiply               BTC
# ...             ...      ...      ...  ...      ...             ...               ...
# 2021-11-07  4638.45  4507.27  4521.41  ...  4617.13          direct
# 2021-11-08  4823.95  4616.63  4617.13  ...  4810.97          direct
# 2021-11-09  4841.12  4710.00  4810.97  ...  4732.07          direct
# 2021-11-10  4865.94  4488.21  4732.07  ...  4632.98          direct
# 2021-11-11  4742.62  4579.28  4632.98  ...  4727.10          direct
#
# ...

# %%
df = df.drop(['conversionType','conversionSymbol'], axis=1)
df
# Out:
#                high      low     open  volumefrom      volumeto    close
# time
# 2016-05-21    14.12    13.10    13.73  1507863.99  2.112540e+07    14.01
# 2016-05-22    14.42    13.64    14.01  1053212.08  1.503404e+07    14.27
# 2016-05-23    14.67    13.38    14.27  1239935.89  1.667496e+07    13.45
# 2016-05-24    13.81    11.90    13.45   227000.82  2.893204e+06    12.62
# 2016-05-25    13.03    11.71    12.63  1731847.61  2.167819e+07    12.52
# ...             ...      ...      ...         ...           ...      ...
# 2021-11-07  4638.45  4507.27  4521.41   162615.74  7.458916e+08  4617.13
# 2021-11-08  4823.95  4616.63  4617.13   295621.95  1.401094e+09  4810.97
# 2021-11-09  4841.12  4710.00  4810.97   278323.93  1.331651e+09  4732.07
# 2021-11-10  4865.94  4488.21  4732.07   453846.25  2.133669e+09  4632.98
# 2021-11-11  4742.62  4579.28  4632.98    90594.71  4.212683e+08  4727.10
#
# [2001 rows x 6 columns]

# %%
close = list(df.close)
date = list(df.volumefrom)
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.scatter(close, date, color ='blue')
 
plt.xlabel("close")
plt.ylabel("starting volume")
plt.title("daily closing prices and volume analysis")
plt.show()

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=BTC&tsym=USD&limit=2000')
df = pd.DataFrame(json.loads(res.content)['Data'])
df = df.set_index('time')
df.index = pd.to_datetime(df.index, unit='s')

# %%
close = list(df.close)
date = list(df.volumefrom)
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.scatter(close, date, color ='green')
 
plt.xlabel("close")
plt.ylabel("starting volume")
plt.title("daily closing prices and volume analysis")
plt.show()

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=ADA&tsym=USD&limit=2000')
df = pd.DataFrame(json.loads(res.content)['Data'])
df = df.set_index('time')
df.index = pd.to_datetime(df.index, unit='s')

# %%
close = list(df.close)
date = list(df.volumefrom)
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.scatter(close, date, color ='red')
 
plt.xlabel("close")
plt.ylabel("starting volume")
plt.title("daily closing prices and volume analysis")
plt.show()

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=DOGE&tsym=USD&limit=2000')
df = pd.DataFrame(json.loads(res.content)['Data'])
df = df.set_index('time')
df.index = pd.to_datetime(df.index, unit='s')

# %%
close = list(df.close)
date = list(df.volumefrom)
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.scatter(close, date, color ='yellow')
 
plt.xlabel("close")
plt.ylabel("starting volume")
plt.title("daily closing prices and volume analysis")
plt.show()

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=XRP&tsym=USD&limit=2000')
df = pd.DataFrame(json.loads(res.content)['Data'])
df = df.set_index('time')
df.index = pd.to_datetime(df.index, unit='s')

# %%
close = list(df.close)
date = list(df.volumefrom)
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.scatter(close, date, color ='pink')
 
plt.xlabel("close")
plt.ylabel("starting volume")
plt.title("daily closing prices and volume analysis")
plt.show()

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=LTC&tsym=USD&limit=2000')
df = pd.DataFrame(json.loads(res.content)['Data'])
df = df.set_index('time')
df.index = pd.to_datetime(df.index, unit='s')

# %%
close = list(df.close)
date = list(df.volumefrom)
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.scatter(close, date, color ='orange')
 
plt.xlabel("close")
plt.ylabel("starting volume")
plt.title("daily closing prices and volume analysis")
plt.show()

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=BNB&tsym=USD&limit=2000')
df = pd.DataFrame(json.loads(res.content)['Data'])
df = df.set_index('time')
df.index = pd.to_datetime(df.index, unit='s')

# %%
close = list(df.close)
date = list(df.volumefrom)
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.scatter(close, date, color ='purple')
 
plt.xlabel("close")
plt.ylabel("starting volume")
plt.title("daily closing prices and volume analysis")
plt.show()

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=USDT&tsym=USD&limit=2000')
df = pd.DataFrame(json.loads(res.content)['Data'])
df = df.set_index('time')
df.index = pd.to_datetime(df.index, unit='s')

# %%
close = list(df.close)
date = list(df.volumefrom)
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.scatter(close, date, color ='black')
 
plt.xlabel("close")
plt.ylabel("starting volume")
plt.title("daily closing prices and volume analysis")
plt.show()

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=BCH&tsym=USD&limit=2000')
df = pd.DataFrame(json.loads(res.content)['Data'])
df = df.set_index('time')
df.index = pd.to_datetime(df.index, unit='s')

# %%
close = list(df.close)
date = list(df.volumefrom)
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.scatter(close, date, color ='purple')
 
plt.xlabel("close")
plt.ylabel("starting volume")
plt.title("daily closing prices and volume analysis")
plt.show()

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=ETC&tsym=USD&limit=2000')
df = pd.DataFrame(json.loads(res.content)['Data'])
df = df.set_index('time')
df.index = pd.to_datetime(df.index, unit='s')

# %%
close = list(df.close)
date = list(df.volumefrom)
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.scatter(close, date, color ='maroon')
 
plt.xlabel("close")
plt.ylabel("starting volume")
plt.title("daily closing prices and volume analysis")
plt.show()

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=DASH&tsym=USD&limit=2000')
df = pd.DataFrame(json.loads(res.content)['Data'])
df = df.set_index('time')
df.index = pd.to_datetime(df.index, unit='s')

# %%
close = list(df.close)
date = list(df.volumefrom)
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.scatter(close, date, color ='magenta')
 
plt.xlabel("close")
plt.ylabel("starting volume")
plt.title("daily closing prices and volume analysis")
plt.show()
